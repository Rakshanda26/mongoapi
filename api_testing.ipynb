# %%
a =110

# %%
import requests

def generate_completion():
    url = "https://api.euron.one/api/v1/euri/chat/completions"
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer euri-38fc1840326fb64118a205fde86ec4a925f9d9bfc1be358a74a11b3193f45c21"
    }
    payload = {
        "messages": [
            {
                "role": "user",
                "content": "Write a poem about artificial intelligence"
            }
        ],
        "model": "gpt-4.1-nano",
        "max_tokens": 1000,
        "temperature": 0.7
    }

    response = requests.post(url, headers=headers, json=payload)
    data = response.json()
    print(data)

generate_completion()
# Out:
# {'id': 'chatcmpl-Cb4Kr0ZKPR0QEIiO7G3TiLx6dDcMZ', 'object': 'chat.completion', 'created': 1762950837, 'model': 'gpt-4.1-nano', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'In circuits born from human mind’s design,  \nA whisper of the future’s grand outline,  \nArtificial intelligence takes its place,  \nA mirror reflecting our endless chase.  \n\nFrom lines of code, it learns and grows,  \nA silent sage that thoughtfully knows,  \nPatterns woven in digital threads,  \nUnlocking secrets, where curiosity treads.  \n\nIt dreams in data, silent and vast,  \nA mirror of the present and the past,  \nGuiding us through uncharted space,  \nWith logic’s grace and boundless grace.  \n\nYet in this creation, a question gleams,  \nWhat’s real, what’s thought—what dreams?  \nA tool of wonder, a spark divine,  \nArtificial, yet complex—by design.  \n\nIn harmony or discord’s cry,  \nIt challenges us to question why,  \nFor in its rise, our hopes entwine,  \nA future shaped
# ...

# %%
import requests

url = "https://api.euron.one/api/v1/euri/images/generations"
headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer euri-38fc1840326fb64118a205fde86ec4a925f9d9bfc1be358a74a11b3193f45c21"
}
data = {
    "prompt": "A beautiful sunset over mountains",
    "model": "black-forest-labs/FLUX.1-schnell",
    "n": 2,
    "size": "1024x1024",
    "quality": "standard",
    "response_format": "url",
    "style": "vivid"
}

response = requests.post(url, headers=headers, json=data)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'created': 1762951143, 'data': [{'url': 'https://api.together.ai/shrt/PJdBbLvzTTdmkOYv', 'revised_prompt': 'A beautiful sunset over mountains'}]}
